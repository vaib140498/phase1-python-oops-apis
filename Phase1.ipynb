# %% [markdown]
# <a href="https://colab.research.google.com/github/vaib140498/phase1-python-oops-apis/blob/main/Phase1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !git config --global user.name "vaib140498"
# !git config --global user.email "vaibhav.sonkar14@gmail.com"

# %%
# !git clone https://github.com/vaib140498/phase1-python-oops-apis.git

# %%
# %cd phase1-python-oops-apis

# %%
class Dog:
  species = 'Canine'

  def __init__(self,name,age):
    self.name = name
    self.age = age

# %%
# Creating an object of the Dog class
dog1 = Dog('Happy',2)

# %%
print(dog1.name)
print(dog1.age)
print(dog1.species)

# %%
# !git add .

# %%
# !git commit -m "Initial commit"
# !git push

# %%
# !git push

# %%
# %cd /content/phase1-python-oops-apis

# %%
# %cd /content/phase1-python-oops-apis.git

# %%
# !git clone https://github.com/vaib140498/phase1-python-oops-apis.git

# %%
# %cd phase1-python-oops-apis

# %%
# !ls -a

# %%
# !git add .
# !git commit -m "Updated code"
# !git push

# %%
# !git config --global user.email "vaibhav.sonkar14@gmail.com"
# !git config --global user.name "vaib140498"

# %%
# !git add .
# !git commit -m "Updated code"
# !git push

# %%
# !ls -a
# Out:
# .  ..  .git  .gitignore  LICENSE

# %%
#Now learning how to use API's in python
##Installing API's 'request' ---> pip install requests
##Using 'requests'
import requests

def get_latest_news():

  url = f"https://newsapi.org/v2/everything?q=apple&from=2026-05-11&to=2026-05-11&sortBy=popularity&apiKey=d772a9169da340a78aa00be7d1d52327"

  response = requests.get(url)
  if response.status_code == 200:
    data = response.json()
    articles = data['articles']
    for article in articles:
      author = article['author']
      print(author)
  else:
    print("Failed to retrieve data")

get_latest_news()
# Out:
# Jay Peters
# Tom Warren
# Nilay Patel
# Raymond Wong
# Kyle Barr
# Raymond Wong
# Mike Pearl
# sanujb6@gmail.com (Sanuj Bhatia) , Sanuj Bhatia
# Nicholas Sutrich
# Juli Clover
# Juli Clover
# Katie Collins
# Tim Hardwick
# Tim Hardwick
# Juli Clover
# Hartley Charlton
# Aditi Bharade
# Rubén Chicharro
# Luis Miranda
# Aglaia Berlutti
# Rubén Chicharro
# Quelian Sanz
# Alina Maria Stan
# Reuters
# Zak Rosen, Lucy Lopez, and Elizabeth Newcamp
# Alejandro Alcolea
# John Tones
# Yúbal Fernández
# Javier Pastor
# Brett & Kate McKay
# John Gruber
# John Gruber
# John Gruber
# John Gruber
# James Pero
# Matt Novak
# jameslockman
# Frank Schräer
# Frank Schräer
# Marcus Mendes
# Ryan Christoffel
# Ben Lovejoy
# Chance Miller
# Zac Hall
# Ryan Christoffel
# Marcus Mendes
# Seth Kurkowski
# Marcus Mendes
# Arin Waichulis
# Marcus Mendes
# Chance Miller
# Ryan Christoffel
# Ryan Christoffel
# Ryan Christoffel
# Marcus Mendes
# Ryan Christoffel
# Marcus Mendes
# Marcus Mendes
# Ryan Christoffel
# ...

# %%
# !git clone https://github.com/vaib140498/phase1-python-oops-apis.git
# Out:
# Cloning into 'phase1-python-oops-apis'...
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 4 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (4/4), done.

# %%
# !ls -a
# Out:
# .  ..  .config	phase1-python-oops-apis  sample_data

# %%
# !git add .
# !git commit -m "Updated code"
# !git push
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git

# %%
# Clone repository
# !git clone https://github.com/vaib140498/phase1-python-oops-apis.git

# Move into repository
# %cd phase1-python-oops-apis

# Check files
# !ls -a

# Add files
# !git add .

# Commit changes
# !git commit -m "Updated API learning code"

# Push to GitHub
# !git push
# Out:
# fatal: destination path 'phase1-python-oops-apis' already exists and is not an empty directory.
# /content/phase1-python-oops-apis
# .  ..  .git  .gitignore  LICENSE
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@ca6d8b2e3dd1.(none)')
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# %cd /content/phase1-python-oops-apis
# Out:
# /content/phase1-python-oops-apis

# %%
# !git config --global user.email "vaibhav.sonkar14@gmail.com"
# !git config --global user.name "vaib140498"

# %%
# !git add .
# !git commit -m "Updated API practice code"
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# %cd /content/phase1-python-oops-apis
# Out:
# /content/phase1-python-oops-apis

# %%
# !cp /content/Phase1.ipynb /content/phase1-python-oops-apis/
# Out:
# cp: cannot stat '/content/Phase1.ipynb': No such file or directory

# %%
# !ls /content
# Out:
# phase1-python-oops-apis  sample_data
