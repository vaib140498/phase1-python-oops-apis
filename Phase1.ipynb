# %% [markdown]
# <a href="https://colab.research.google.com/github/vaib140498/phase1-python-oops-apis/blob/main/Phase1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
#Now learning how to use API's in python
##Installing API's 'request' ---> pip install requests
##Using 'requests'
import requests

def get_latest_news():

  url = f"https://newsapi.org/v2/everything?q=apple&from=2026-05-11&to=2026-05-11&sortBy=popularity&apiKey=...."

  response = requests.get(url)
  if response.status_code == 200:
    data = response.json()
    articles = data['articles']
    for article in articles:
      author = article['author']
      print(author)
  else:
    print("Failed to retrieve data")

get_latest_news()
# Out:
# Jay Peters
# Tom Warren
# Nilay Patel
# Raymond Wong
# Kyle Barr
# Raymond Wong
# Mike Pearl
# sanujb6@gmail.com (Sanuj Bhatia) , Sanuj Bhatia
# Nicholas Sutrich
# Juli Clover
# Juli Clover
# Katie Collins
# Tim Hardwick
# Tim Hardwick
# Juli Clover
# Hartley Charlton
# Aditi Bharade
# Rubén Chicharro
# Luis Miranda
# Aglaia Berlutti
# Rubén Chicharro
# Quelian Sanz
# Alina Maria Stan
# Reuters
# Zak Rosen, Lucy Lopez, and Elizabeth Newcamp
# Alejandro Alcolea
# John Tones
# Yúbal Fernández
# Javier Pastor
# Brett & Kate McKay
# John Gruber
# John Gruber
# John Gruber
# John Gruber
# James Pero
# Matt Novak
# jameslockman
# Frank Schräer
# Frank Schräer
# Marcus Mendes
# Ryan Christoffel
# Ben Lovejoy
# Chance Miller
# Zac Hall
# Ryan Christoffel
# Marcus Mendes
# Seth Kurkowski
# Marcus Mendes
# Arin Waichulis
# Marcus Mendes
# Chance Miller
# Ryan Christoffel
# Ryan Christoffel
# Ryan Christoffel
# Marcus Mendes
# Ryan Christoffel
# Marcus Mendes
# Marcus Mendes
# Ryan Christoffel
# Ben Lovejoy
# Bradley C
# Ryan Christoffel
# Ryan Christoffel
# Justin Kahn
# Sponsored Post
# Zac Hall
# Mark Jansen
# はらいさん
# カタヤママコト
# シラクマ
# Kenji P. Miyajima
# Gaurav Sood
# zac.bowden@futurenet.com (Zac Bowden) , Zac Bowden
# Gregori Pujol
# Korben ✨
# Álvaro García M.
# Álvaro García M.
# Guille Lomener
# Alberto García
# Álvaro García M.
# Guille Lomener
# Álvaro García M.
# Tim Anderson
# Alex Harper
# Aisling Irwin, Benjamin Thompson
# Setra
# Jazz Monroe
# Pitchfork
# Jim Vorel
# Rich Edmonds
# Johannes Hiltscher
# Eden Gordon
# Akshay Gangwar
# Kaitlyn Cimino
# Aamir Siddiqui
# DealHunt
# staff@bgr.com (José Adorno)
# staff@bgr.com (José Adorno)
# staff@bgr.com (Noelle Corbett)

# %%
class Dog:
  species = 'Canine'

  def __init__(self,name,age):
    self.name = name
    self.age = age

# %%
# Creating an object of the Dog class
dog1 = Dog('Happy',2)

# %%
print(dog1.name)
print(dog1.age)
print(dog1.species)

# %%
from google.colab import userdata
import requests

def get_latest_news():
  topic = ['apple', 'samsung', 'tesla']
  api_key =userdata.get('apikey')
  url = "https://newsapi.org/v2/everything"
  responses = []
  for i in range(0,len(topic)):
    params = {
      "q": topic[i],
      "from":"2026-05-11",
      "sortBy":"popularity",
      "apiKey":api_key
      }
    response = requests.get(url,params=params)
    responses.append(response)

  for response in responses:
    if response.status_code == 200:
      data = response.json()
      articles = data['articles']

      print("\nTop News\n")

      for article in articles[:5]:
        print(article['title'])
        print(article['url'])
        print()
    else:
      print("Failed to retrieve data")

get_latest_news()
# Out:
# Top News
#
# What Happens When You Try to Treat OCD With Psilocybin
# https://www.wired.com/story/book-excerpt-how-to-not-know-simone-stolzoff/
#
# Everyone at the Musk v. Altman Trial Is Using Fancy Butt Cushions
# https://www.wired.com/story/fancy-butt-pillows-musk-v-altman-trial/
#
# Apple brings encrypted RCS chats to iPhone
# https://www.theverge.com/tech/928141/apple-ios-26-5-rcs-messages-iphone-google-android
#
# The Apple Studio Display could have been so much more
# https://www.theverge.com/tech/929015/apple-studio-display-2026
#
# iOS 27 might add a lot more customization to the Camera app
# https://www.theverge.com/tech/929152/apple-ios-27-camera-app-customization
#
#
# Top News
#
# The Apple Studio Display could have been so much more
# https://www.theverge.com/tech/929015/apple-studio-display-2026
#
# Samsung’s Galaxy XR Is the Future of Wearables—Just Not VR Headsets
# https://gizmodo.com/samsungs-galaxy-xr-is-the-future-of-wearables-just-not-vr-headsets-2000757782
#
# The Trump Phone Is Seriously, for Sure, Without a Doubt Shipping This Week (Allegedly)
# https://gizmodo.com/the-trump-phone-is-seriously-for-sure-without-a-doubt-shipping-this-week-allegedly-2000757976
#
# Google is Unleashing Gemini on Android Users
# https://gizmodo.com/google-is-unleashing-gemini-on-android-users-2000757660
#
# Google’s Next Phone Chip Will Be Faster, and Still Not Fast Enough
# https://gizmodo.com/googles-next-phone-chip-will-be-faster-and-still-not-fast-enough-2000757031
#
#
# Top News
#
# Sam Altman says Elon Musk’s mind games were damaging OpenAI
# https://www.theverge.com/ai-artificial-intelligence/928861/openai-sam-altman-elon-musk-damage
#
# Sam Altman was winning on the stand, but it might not be enough
# https://www.theverge.com/ai-artificial-intelligence/929129/sam-altman-testimony-elon-musk-openai-trial
#
# What to know as Trump visits Xi in China
# https://www.bbc.com/news/articles/cyv2n7l1z14o
#
# Does Trump need China to end the war in Iran?
# https://www.bbc.co.uk/sounds/play/p0nl1r5w?at_campaign=rss
#
# Sam Altman Testifies That Elon Musk Wanted Control of OpenAI
# https://yro.slashdot.org/story/26/05/12/2231210/sam-altman-testifies-that-elon-musk-wanted-control-of-openai

# %%
from google.colab import userdata
import requests

def get_latest_TopNews(topics):

  api_key = userdata.get('apikey')
  url = "https://newsapi.org/v2/everything"

  all_articles = []

  for topic in topics:
    params = {
        "q": topic,
        "from": "2026-05-11",
        "sortBy": "popularity",
        "apiKey": api_key
    }
    response = requests.get(url, params=params)
    if response.status_code == 200:
      data = response.json()
      articles = data['articles']
      for article in articles:
        article['search_topic'] = topic
      all_articles.extend(articles[:5])
    else:
      print(f"Failed to retrieve {topic} data : {response.status_code}")

  print("\nTop News\n")
  for article in all_articles:
    print(article['title'])
    print(article['url'])
    print()

topics = ['Samsung', 'Sony', 'Ubisoft', 'BJP']
topics1 = ['AI Agent', 'Computer Vision']

get_latest_TopNews(topics)
get_latest_TopNews(topics1)
# Out:
# Top News
#
# The Apple Studio Display could have been so much more
# https://www.theverge.com/tech/929015/apple-studio-display-2026
#
# Samsung’s Galaxy XR Is the Future of Wearables—Just Not VR Headsets
# https://gizmodo.com/samsungs-galaxy-xr-is-the-future-of-wearables-just-not-vr-headsets-2000757782
#
# The Trump Phone Is Seriously, for Sure, Without a Doubt Shipping This Week (Allegedly)
# https://gizmodo.com/the-trump-phone-is-seriously-for-sure-without-a-doubt-shipping-this-week-allegedly-2000757976
#
# Google’s Next Phone Chip Will Be Faster, and Still Not Fast Enough
# https://gizmodo.com/googles-next-phone-chip-will-be-faster-and-still-not-fast-enough-2000757031
#
# Google is Unleashing Gemini on Android Users
# https://gizmodo.com/google-is-unleashing-gemini-on-android-users-2000757660
#
# Sony upgraded its wearable AC so it’s cooler and better at hugging your neck
# https://www.theverge.com/tech/928220/sony-reon-pocket-pro-plus-personal-wearable-air-conditioner
#
# Sony’s Cyberpunk Neck Cooler Is Now Better at Chilling Your Spine
# https://gizmodo.com/sonys-cyberpunk-neck-cooler-is-now-better-at-chilling-your-spine-2000757468
#
# I test audio products for a living, and between the Sony's WH-1000XM6 and Bose QC Ultra Headphones (2nd Gen), this is what I think you should buy
# https://www.androidcentral.com/accessories/headphones/should-you-buy-sony-wh-1000xm6-over-bose-qc-ultra-2nd-gen-headphones
#
# The Vivo X300 FE is a standout compact flagship — there's just one issue
# https://www.androidcentral.com/phones/vivo/vivo-x300-fe-review
#
# 11 Reasons to Wait for the iPhone 18 Pro
# https://www.macrumors.com/2026/05/11/reasons-to-wait-for-the-iphone-18-pro-max/
#
# You Can Pay To Join A Assassin’s Creed Black Flag Resynced Treasure Hunt And Find A $500,000 Chest Ubisoft Had Buried In The Caribbean
# https://kotaku.com/you-can-pay-to-join-a-assassins-creed-black-flag-resynced-treasure-hunt-and-find-a-500000-chest-ubisoft-had-buried-in-the-caribbean-2000695697
#
# Police Arrest Man Who Threatened To Blow Up Nintendo Headquarters
# https://kotaku.com/nintendo-headquarters-kyoto-bomb-threat-arrest-japan-2000695654
#
# Un vrai trésor de Black Flag Resynced de 500 000 $ est à trouver aux Caraïbes
# https://www.journaldugeek.com/2026/05/13/un-vrai-tresor-de-black-flag-resynced-de-500-000-est-a-trouver-aux-caraibes/
#
# Leak: Assassin's Creed Hexe mit (sehr) altem Fan-Liebling in Würzburg
# https://www.golem.de/sonstiges/zustimmung/auswahl.html?from=https%3A%2F%2Fwww.golem.de%2Fnews%2Fleak-assassin-s-creed-hexe-mit-sehr-altem-fan-liebling-in-wuerzburg-2605-208619.html&referer=https%3A%2F%2Ft.co%2Fe3b7bfed2c
#
# Se presentó como uno de los primeros AAAA de la historia y ahora ya cuesta casi lo mismo que un paquete de pipas
# https://www.vidaextra.com/accion/se-presento-como-uno-primeros-aaaa-historia-ahora-cuesta-casi-paquete-pipas
#
# UP Cabinet expansion signals BJP’s 2027 caste strategy: Sticking to a winning formula
# https://indianexpress.com/article/political-pulse/up-cabinet-expansion-signals-bjps-2027-caste-strategy-sticking-to-a-winning-formula-10682977/
#
# In Tamil Nadu flux, BJP spots an opening: Flexible DMK, weaker Opposition
# https://indianexpress.com/article/political-pulse/in-tamil-nadu-flux-bjp-spots-an-opening-flexible-dmk-weaker-opposition-10685263/
#
# BJP government delayed NEET leak probe since party’s youth wing leader is involved, Congress claims
# https://indianexpress.com/article/cities/jaipur/bjp-govt-delay-neet-leak-probe-youth-wing-leader-congress-10686884/
#
# ‘Sacrifice expected only from public?’: BJP leader’s massive convoy sparks row after PM’s ‘save fuel’ appeal
# https://indianexpress.com/article/india/sacrifice-expected-only-from-public-bjp-leaders-massive-convoy-sparks-row-after-pms-save-fuel-appeal-10686460/
#
# Assam CM oath ceremony LIVE Updates: US envoy Sergio Gor arrives for Himanta Biswa Sarma’s swearing-in
# https://indianexpress.com/article/india/himanta-biswa-sarma-assam-cm-swearing-in-oath-ceremony-cabinet-ministers-list-live-updates-10684704/
#
#
# Top News
#
# Overworked AI Agents Turn Marxist, Researchers Find
# https://www.wired.com/story/overworked-ai-agents-turn-marxist-study/
#
# You can make an app for that
# https://www.theverge.com/tech/928905/vibe-code-personal-software-revolution
#
# Joanna Stern is not a robot, but she lived with them
# https://www.theverge.com/podcast/926752/joanna-stern-i-am-not-a-robot-new-things-media-youtube-ai-automation
#
# The border is everywhere
# https://www.theverge.com/report/928726/border-security-expo-cbp-ice-dhs-surveillance
#
# Siri’s Total Chatbot Makeover Is Imminent With iOS 27
# https://gizmodo.com/siri-total-chatbot-makeover-is-imminent-with-ios-27-2000757747
#
# Joanna Stern is not a robot, but she lived with them
# https://www.theverge.com/podcast/926752/joanna-stern-i-am-not-a-robot-new-things-media-youtube-ai-automation
#
# Samsung’s Galaxy XR Is the Future of Wearables—Just Not VR Headsets
# https://gizmodo.com/samsungs-galaxy-xr-is-the-future-of-wearables-just-not-vr-headsets-2000757782
#
# AI robot changes your tires and balances them too
# https://www.foxnews.com/tech/ai-robot-changes-tires-balances
#
# Smart Glasses With Subscriptions Are As Bad as They Sound
# https://gizmodo.com/smart-glasses-with-subscriptions-are-as-bad-as-they-sound-2000755908
#
# Interfaze: A new model architecture built for high accuracy at scale
# https://interfaze.ai/blog/interfaze-a-new-model-architecture-built-for-high-accuracy-at-scale
